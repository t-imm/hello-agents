# %%
from ReAct import HelloAgentsLLM
from Reflection import ReflectionAgent

# %%
# 1. 初始化LLM客户端 (请确保你的 .env 和 llm_client.py 文件配置正确)
try:
    llm_client = HelloAgentsLLM()
except Exception as e:
    print(f"初始化LLM客户端时出错: {e}")
    exit()

# 2. 初始化 Reflection 智能体，设置最多迭代2轮
agent = ReflectionAgent(llm_client, max_iterations=2)

# 3. 定义任务并运行智能体
task = "编写一个Python函数，找出1到n之间所有的素数 (prime numbers)。"
agent.run(task)
# Out:
# --- 开始处理任务 ---
# 任务: 编写一个Python函数，找出1到n之间所有的素数 (prime numbers)。
#
# --- 正在进行初始尝试 ---
# 🧠 正在调用 deepseek-v4-flash 模型...
# ✅ 大语言模型响应成功:
# def find_primes(n: int) -> list[int]:
#     """Return all prime numbers from 1 to n inclusive.
#
#     Args:
#         n: The upper bound, inclusive, for finding prime numbers.
#
#     Returns:
#         A list of all prime numbers in the range [1, n].
#
#     Raises:
#         TypeError: If n is not an integer.
#     """
#     if not isinstance(n, int):
#         raise TypeError("n must be an integer")
#
#     if n < 2:
#         return []
#
#     is_prime = [True] * (n + 1)
#     is_prime[0] = is_prime[1] = False
#
#     for number in range(2, int(n ** 0.5) + 1):
#         if is_prime[number]:
#             for multiple in range(number * number, n + 1, number):
#                 is_prime[multiple] = False
#
#     return [number for number in range(2, n + 1) if is_prime[number]]
# 📝 记忆已更新，新增一条 'execution' 记录。
#
# --- 第 1/2 轮迭代 ---
#
# -> 正在进行反思...
# 🧠 正在调用 deepseek-v4-flash 模型...
# ✅ 大语言模型响应成功:
# 时间复杂度：O(n log log n)；空间：O(n)。
#
# 当前代码已是埃拉托斯特尼筛法，不是低效试除法；算法选择上已接近实际最优。线性筛理论上 O(n)，但 Python 中常数更大、额外循环和取模开销明显，通常不会显著快于当前写法；分段筛只降低内存峰值，不改变时间复杂度。
#
# 主要瓶颈不在算法选择，而在实现常数：
# - 内层用 Python 循环逐个标记合数，开销大。
# - `list[bool]` 是对象引用数组，缓存和内存不友好。
# - `int(n ** 0.5)` 有浮点开方风险，应使用 `math.isqrt(n)`。
#
# 可行优化方向：
# - 用 `bytearray` 替代 `list[bool]`。
# - 用切片批量标记：`is_prime[p*p:n+1:p] = b'\x00' * count`。
# - 单独处理 2，只筛奇数，减少约一半操作。
# - 超大 n 用分段筛降低内存峰值。
# - 平方根上限改用 `math.isqrt(n)`。
#
# 结论：算法层面无需改进；上述均为常数级或内存级优化。
# 📝 记忆已更新，新增一条 'reflection' 记录。
#
# ✅ 反思认为代码已无需改进，任务完成。
#
# --- 任务完成 ---
# 最终生成的代码:
# def find_primes(n: int) -> list[int]:
#     """Return all prime numbers from 1 to n inclusive.
#
#     Args:
#         n: The upper bound, inclusive, for finding prime numbers.
#
#     Returns:
#         A list of all prime numbers in the range [1, n].
#
#     Raises:
#         TypeError: If n is not an integer.
#     """
#     if not isinstance(n, int):
#         raise TypeError("n must be an integer")
#
#     if n < 2:
#         return []
#
#     is_prime = [True] * (n + 1)
#     is_prime[0] = is_prime[1] = False
#
#     for number in range(2, int(n ** 0.5) + 1):
#         if is_prime[number]:
#             for multiple in range(number * number, n + 1, number):
#                 is_prime[multiple] = False
#
#     return [number for number in range(2, n + 1) if is_prime[number]]
# 'def find_primes(n: int) -> list[int]:\n    """Return all prime numbers from 1 to n inclusive.\n\n    Args:\n        n: The upper bound, inclusive, for finding prime numbers.\n\n    Returns:\n        A list of all prime numbers in the range [1, n].\n\n    Raises:\n        TypeError: If n is not an integer.\n    """\n    if not isinstance(n, int):\n        raise TypeError("n must be an integer")\n\n    if n < 2:\n        return []\n\n    is_prime = [True] * (n + 1)\n    is_prime[0] = is_prime[1] = False\n\n    for number in range(2, int(n ** 0.5) + 1):\n        if is_prime[number]:\n            for multiple in range(number * number, n + 1, number):\n                is_prime[multiple] = False\n\n    return [number for number in range(2, n + 1) if is_prime[number]]'
