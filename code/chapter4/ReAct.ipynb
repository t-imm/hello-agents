# %%
from ReAct import HelloAgentsLLM, ReActAgent
from tools import ToolExecutor, search

# %%
llm = HelloAgentsLLM()
tool_executor = ToolExecutor()
search_desc = "一个网页搜索引擎。当你需要回答关于时事、事实以及在你的知识库中找不到的信息时，应使用此工具。"
tool_executor.registerTool("Search", search_desc, search)
agent = ReActAgent(llm_client=llm, tool_executor=tool_executor)
question = "华为最新的手机是哪一款？它的主要卖点是什么？"
agent.run(question)
# Out:
# 工具 'Search' 已注册。
#
# --- 第 1 步 ---
# 🧠 正在调用 deepseek-v4-flash 模型...
# ✅ 大语言模型响应成功:
# Thought: 需要先确认截至当前时间华为最新发布的手机型号，再收集其官方或权威来源介绍的主要卖点。由于信息可能随时间变化，必须使用网页搜索。
# Action: Search[华为 最新手机 2026 发布 型号 主要卖点]
# 🤔 思考: 需要先确认截至当前时间华为最新发布的手机型号，再收集其官方或权威来源介绍的主要卖点。由于信息可能随时间变化，必须使用网页搜索。
# 🎬 行动: Search[华为 最新手机 2026 发布 型号 主要卖点]
# 🔍 正在执行 [SerpApi] 网页搜索: 华为 最新手机 2026 发布 型号 主要卖点
# 👀 观察: [1] 2026年华为手机各系列介绍及选购指南（9月份更新） ...
# 本文主要介绍华为各系列机型。本文长期更新，建议收藏。 注：本文商品链接均来自京东自营，可放心购买。 华为今年新机都只有纯血鸿蒙系统版本可选，介意者可以考虑荣耀 ...
#
# [2] 华为发布会- 华为官网
# 2026.06.01nova 16 系列及全场景新品发布会华为全新发布nova 16 系列、MatePad Pro Max、FreeClip 2 典藏版耳夹耳机等产品及配件。 2026年四月. 2026年. 四月.
#
# [3] 华为发布HUAWEI Pura 80系列，让影像远超想象
# HUAWEI Pura 80 Pro+搭载1英寸高动态主摄，配合红枫原色摄像头的像素级色彩校准，明暗细节清晰，色彩还原精准。HUAWEI Pura 80 Ultra首发“聚光宝盒”1英寸 ...
#
# --- 第 2 步 ---
# 🧠 正在调用 deepseek-v4-flash 模型...
# ✅ 大语言模型响应成功:
# Thought: 官网信息显示 2026 年 6 月 1 日华为发布了 nova 16 系列，这是目前搜索到的最新手机系列。但还需要确认该系列的核心卖点，尤其是影像、系统、设计等官方宣传点，因此继续搜索。
# Action: Search[华为 nova 16 系列 主要卖点 影像 鸿蒙 2026]
# 🤔 思考: 官网信息显示 2026 年 6 月 1 日华为发布了 nova 16 系列，这是目前搜索到的最新手机系列。但还需要确认该系列的核心卖点，尤其是影像、系统、设计等官方宣传点，因此继续搜索。
# 🎬 行动: Search[华为 nova 16 系列 主要卖点 影像 鸿蒙 2026]
# 🔍 正在执行 [SerpApi] 网页搜索: 华为 nova 16 系列 主要卖点 影像 鸿蒙 2026
# 👀 观察: [1] HUAWEI nova 16 - 华为官网
# HUAWEI nova 16，利落直屏，轻盈质感，6.68 英寸护眼屏，5500 尼特峰值亮度，红枫影像，7000 mAh 电池，鸿蒙智慧通信。
#
# [2] nova 16 系列及全场景新品发布会- 华为官网
# nova 16 系列及全场景新品发布会 ; HUAWEI nova 16 Pro. ￥3899 起 ; HUAWEI MatePad Pro Max. ￥6499 起 ; HUAWEI nova 16 Ultra. ￥4699 起 ; HUAWEI nova 16. ￥2999 起.
#
# [3] 华为nova 16系列及全场景新品亮相，市场承压下坚守产品力
# 华为nova 16系列坚持核心配置不降档、体验不打折，全系搭载麒麟9010S旗舰芯片，搭配HarmonyOS 6.1与方舟引擎，保障多任务与游戏场景稳定流畅。续航方面 ...
#
# --- 第 3 步 ---
# 🧠 正在调用 deepseek-v4-flash 模型...
# ✅ 大语言模型响应成功:
# Thought: 根据搜索历史，华为在2026年6月1日发布了 nova 16 系列，这是目前最新的手机系列。可从官网和发布会报道中提炼其主要卖点。
# Action: Finish[华为最新发布的是 HUAWEI nova 16 系列，包括 HUAWEI nova 16、nova 16 Pro、nova 16 Ultra。其主要卖点包括：全系搭载麒麟9010S旗舰芯片，配合 HarmonyOS 6.1 与方舟引擎；HUAWEI nova 16 配备 6.68 英寸护眼屏、5500 尼特峰值亮度、红枫影像、7000 mAh 电池，并支持鸿蒙智慧通信；系列整体强调核心配置不降档、体验不打折，在影像、续航和系统流畅度方面表现突出。]
# 🤔 思考: 根据搜索历史，华为在2026年6月1日发布了 nova 16 系列，这是目前最新的手机系列。可从官网和发布会报道中提炼其主要卖点。
# 🎉 最终答案: 华为最新发布的是 HUAWEI nova 16 系列，包括 HUAWEI nova 16、nova 16 Pro、nova 16 Ultra。其主要卖点包括：全系搭载麒麟9010S旗舰芯片，配合 HarmonyOS 6.1 与方舟引擎；HUAWEI nova 16 配备 6.68 英寸护眼屏、5500 尼特峰值亮度、红枫影像、7000 mAh 电池，并支持鸿蒙智慧通信；系列整体强调核心配置不降档、体验不打折，在影像、续航和系统流畅度方面表现突出。
# '华为最新发布的是 HUAWEI nova 16 系列，包括 HUAWEI nova 16、nova 16 Pro、nova 16 Ultra。其主要卖点包括：全系搭载麒麟9010S旗舰芯片，配合 HarmonyOS 6.1 与方舟引擎；HUAWEI nova 16 配备 6.68 英寸护眼屏、5500 尼特峰值亮度、红枫影像、7000 mAh 电池，并支持鸿蒙智慧通信；系列整体强调核心配置不降档、体验不打折，在影像、续航和系统流畅度方面表现突出。'
